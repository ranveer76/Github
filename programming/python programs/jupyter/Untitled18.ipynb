# %%
9//1.56
# Out:
# 5.0

# %%
global x,j,K
def G():
    if (((x==0 or j==0 or x==K-1)or((x==1 or x==K-2)and(j==K-1))or((x>=K//(1.45))and(j==K-1 or j>=K//2)))and(not(((x>K//(1.45) and x<K-1)and(j>=K//2 and j<K-1))or((x==0 or x==K-1)and(j==0 or j==K-1))))):
        print('*',end='')
    else:
        print(' ',end='')
    
def H():
    if ((x==K//2 or j==0 or j==K-1)):
        print('*',end='')
    else:
        print(' ',end='')
    
def I():
    if x==0 or j==K//2 or x==K-1:
        print('*',end='')
    else:
        print(' ',end='')

def J():
    if (((x==K-1 and(j<=K//2 and j>=0))or(((x<=K-2 and x>(K//2)+1) and(j==0)))or x==0 or j==K//2))and(not(x==K-1 and(j==0 or j==K//2))):
        print('*',end='')
    else:
        print(' ',end='')
        
def Xo():
    if ((x==j+1 or x+j==K-2)and j>2) or j==2:
        print('*',end='')
    else:
        print(' ',end='')

def L():
    if x==K-1 or j==0:
        print('*',end='')
    else:
        print(' ',end='')
        
def M():
    if (j==0 or j==K-1)or(x<=K//2 and(j==x or x+j==K-1)):
        print('*',end='')
    else:
        print(' ',end='')
        
def N():
    if j==0 or j==K-1 or j==x:
        print('*',end='')
    else:
        print(' ',end='')

def P():
    if j==0 or ((x==0 or x==K//2)and(j!=K-1))or(j==K-1 and(x>0 and x<K//2)):
        print('*',end='')
    else:
        print(' ',end='')
def Q():
    if ((j==0 or j==K-2)and(x<K-1 and x>0)) or ((x==0 or x==K-1)and(j>0 and j<K-2)) or (j==x and x>K//2):
        print('*',end='')
    else:
        print(' ',end='')
def R():
    if j==0 or (x==j and x>K//2) or ((x==0 or x==K//2)and(j!=K-1))or(j==K-1 and(x>0 and x<K//2)):
        print('*',end='')
    else:
        print(' ',end='') 
        
def S():
    if ((x==0 or x==K//2 or x==K-1)and(j>0 and j<K-1))or(j==0 and(x<K//2 and x>0))or(j==K-1 and(x>K//2 and x<K-1))or((x==1 and j==K-1)or(x==K-2 and(j==0))):
        print('*',end='')
    else:
        print(' ',end='')
def T():
    if x==0 or j==K//2:
        print('*',end='')
    else:
        print(' ',end='')
def x1():
    if x==j or j+x==K-1:
        print('*',end='')
    else:
        print(' ',end='')
def Y():
    if (j==K//2 and x>K//2)or(x==j or x+j==K-1)and(x<=K//2):
        print('*',end='')
    else:
        print(' ',end='')
def Z():
    if j+x==K-1 or x==0 or x==K-1:
        print('*',end='')
    else:
        print(' ',end='')
def W():
    if ((x==j or x+j==K-1)and(x>=K//2))or j==0 or j==K-1:
        print('*',end='')
    else:
        print(' ',end='')
def U():
    if (x==K-1 or j==0 or j==K-1)and not(x==K-1 and(j==0 or j==K-1)):
        print('*',end='')
    else:
        print(' ',end='')

def O():
    if((x==0 or x==K-1 or j==0 or j==K-1))and not((x==0 or x==K-1)and(j==0 or j==K-1)):
        print('*',end='')
    else:
        print(' ',end='')
        
def o():
    if((x==(K//2)-1 or x==K-1 or j==(K//2)-1 or j==K-1))and not(((x==(K//2)-1 or x==K-1)and(j==(K//2)-1 or j==K-1))or((j<(K//2)-1)or(x<(K//2)-1))):
        print('*',end='')
    else:
        print(' ',end='')
def u():
    if (x==K-1 or j==(K//2)-1 or j==K-1)and not((x==K-1 and(j==(K//2)-1 or j==K-1))or((x<(K//2)-1)or(j<(K//2)-1))):
        print('*',end='')
    else:
        print(' ',end='')
def X():
        if ((x==K-1)or(j==K//2)or(x==2 and (j<=(K//2)))) and not(x==1):
            print('*',end='')
        else:
            print(' ',end='')
def e():
        if (x==(K//2)-1 or x==K-1 or(j==K-1) or j==(K//2)-1 or x==((K//2)+(K//4)-1))and not((j<(K//2)-1)or ((x>(K//2)+(K//4)-1)and(j==K-1)) or(j==K-1 and(x==(K//2)-1))or(x<(K//2)-1)or((j==(K//2)-1)and(x==K-1 or x==(K//2)-1))):
            print('*',end='')
        else:
            print(' ',end='')
def a():
        if (x==(K//2)-1 or (j==(K//2)-1)or x==K-1 or x==((K//2)+(K//4))-1 or j==K-1)and not(((x<=((K//2)+(K//4))-1)and(j==(K//2)-1))or(x<(K//2)-1)or(j<(K//2)-1)or((x==K-1 or(x==(K//2)-1))and((j==(K//2)-1)or(j==K-1)))):
            print('*',end='')
        else:
            print(' ',end='')
def b():
    if ((x==K-1 or x==K//2)and(j<K-1)) or j==0 or (j==K-1 and(x<K-1 and x>K//2)):
        print('*',end='')
    else:
        print(' ',end='')
def d1():
    if ((x==K-1 or x==K//2)and(j>0)) or j==K-1 or (j==0 and(x<K-1 and x>K//2)):
        print('*',end='')
    else:
        print(' ',end='')
def f():
        if (x==0 and j>2) or x==K//2 or (j==2 and x>0):
            print('*',end='')
        else:
            print(' ',end='')
def h():
    if (x==K//2 and j<K-1)or j==0 or (j==K-1 and x>K//2):
        print('*',end='')
    else:
        print(' ',end='')
def j1():
    if (((x==K-1 and(j<=K//2 and j>=0))or(((x<=K-2 and x>(K//2)+1) and(j==0)))or (x==2 and j<K//2) or j==K//2))and(not((x==1)or(x==K-1 and(j==0 or j==K//2)))):
        print('*',end='')
    else:
        print(' ',end='')
def g():
    if (x==0 and j>=K-2)or(x==K//2 and j==0)or((x==0 or x==K-2 or x==(K//2)-1 or x==(K//2)+1)and(j>0 and j<K-3)or((j==0 or j==K-3)and ((x>0 and x<(K//2)-1) or (x>(K//2)+1 and x<K-2)))):
        print('*',end='')
    else:
        print(' ',end='')
def k():
    pass
def l():
    pass
def m():
    if((x==K//2 and (j!=(K//2) and j!=0 and j!=K-1))or((j==0 or j==(K//2) or j==K-1) and x>(K//2))):
        print('*',end='')
    else:
        print(' ',end='')
def n1():
    if (x==K//2 and(j!=1 and j!=K-1))or((j==1 or j==K-1)and x>K//2):
        print('*',end='')
    else:
        print(' ',end='')
def p():
    if ((j==(K//2)-1)) or ((x==0 or x==K//2)and(j!=K-1 and j>(K//2)-1))or(j==K-1 and(x>0 and x<K//2)):
        print('*',end='')
    else:
        print(' ',end='')
def q():
    if ((j==K-1 or (j==0 and x<K//2)) and x>=(K//2)-3)or((x==K//2 or x==0) and j!=0):
        print('*',end='')
    else:
        print(' ',end='')
def r():
    if (j==0 and x>=(K//2)-1)or((x==(K//2)-1 and(j!=1)))or((j==1) and x==K//2):
        print('*',end='')
    else:
        print(' ',end='')
def s():
    pass
def t():
    if (j==K//2 and x!=K-1)or(x==(K//2)-1)or(x==K-1 and j>K//2):
        print('*',end='')
    else:
        print(' ',end='')
def v():
    pass
def w():
    if (((x==j+1 or x+j==K+1)and(x>(K//2)+1))or j==1 or j==K-1)and x>=K//2:
        print('*',end='')
    else:
        print(' ',end='')
def xt():
    if (x==j or j+x==K)and(x>1 and j>=1):
        print('*',end='')
    else:
        print(' ',end='')
def c():
    if (((x==(K//2)-2 or x==K-1) and j>(K//2)-2)or (j==(K//2)-2 and (x>(K//2)-2 and x<K-1))):
        print('*',end='')
    else:
        print(' ',end='')
def y():
    if ((x+j==K-1)or(x==j and x<K//2)):
        print('*',end='')
    else:
        print(' ',end='')
def z():
    if j+x==K+2 or ((x==(K//2)-1 or x==K-1)and(j>(K//2)-1)):
        print('*',end='')
    else:
        print(' ',end='')
def V():
    pass
n=input()
K=int(input())

d={'k':k,'c':c,'l':l,'m':m,'n':n1,'p':p,'q':q,'V':V,'z':z,'y':y,'x':xt,'w':w,'v':v,'t':t,'s':s,'r':r,'h':h,'j':j1,'g':g,'f':f,'b':b,'d':d1,'I':I,'U':U,'O':O,'A':A,'E':E,'o':o,'u':u,'i':X,'e':e,'a':a,'B':B,'C':C,'D':D,'F':F,'G':G,'H':H,'J':J,'K':Xo,'L':L,'M':M,'N':N,'P':P,'Q':Q,'R':R,'S':S,'T':T,'W':W,'X':x1,'Y':Y,'Z':Z}

if K>=7:
    if K%2==0:
        K+=1
    for x in range(K):
        for i in n:
            for j in range(K//2):
                print(' ',end='')

            for j in range(K):
                d[i]()
                    
        print()
input('press enter to exit')
# Out:
# abc
# 9
#                  *
#                  *
#                  *               ******
#         ****     *              *
#             *    ********       *
#         *****    *       *      *
#        *    *    *       *      *
#        *    *    *       *      *
#         ****     ********        ******
# press enter to exit
# ''

# %%
K=int(input())
for x in range(K):
    for j in range(K):
        if ((j==K-1 or (j==0 and x<K//2)) and x>=(K//2)-3)or((x==K//2 or x==0) and j!=0):
            print('*',end='')
        else:
            print(' ',end='')
    print()
# Out:
# 9
#  ********
# *       *
# *       *
# *       *
#  ********
#         *
#         *
#         *
#         *

# %%
K=int(input())
for x in range(K):
    for j in range(K):
        if (j==K//2 and x!=K-1)or(x==(K//2)-1)or(x==K-1 and j>K//2):
            print('*',end='')
        else:
            print(' ',end='')
    print()
# Out:
# 9
#     *
#     *
#     *
# *********
#     *
#     *
#     *
#     *
#      ****

# %%
K=int(input())
for x in range(K):
    for j in range(K):
        if (j==0 and x>=(K//2)-1)or((x==(K//2)-1 and(j!=1)))or((j==1) and x==K//2):
            print('*',end='')
        else:
            print(' ',end='')
    print()
# Out:
# 5
#
# * ***
# **
# *
# *
