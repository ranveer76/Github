# %%
def C():
    global to,xo
    if x<K//2 and to>=1:
        ze=to-1
        le=xo
    if x>=K//2:
        ze=to+1
        le=xo+1
    if ((j==0) or(x<K//2 and j==to)):
        print('*',end='')
        to=ze
    elif (x==xo and j==to)or (x==K-1 and j==K-1):
        print('*',end='')
        to=ze
        xo=le
    else:
        print(' ',end='')
K=int(input())
to=K-1
xo=(K//2)
for x in range(K):
    for j in range(K):
        C()
    print()
# Out:
# 8
# *     *
# *   *
# * *
# *
# **
# *  *
# *    *
# *      *

# %%
global x,j,K
def A():
    if (x==0 or j==0 or j==K-1 or x==K//2)and not(x==0 and (j==0 or j==K-1)):
        print('*',end='')
    else:
        print(' ',end='')

def B():
    if (x==0 or x==K-1 or x==K//2 or j==K-1 or j==0)and(not(((x==0 or x==K-1 or x==K//2) and (j==K-1)))):
        print('*',end='')
    else:
        print(' ',end='')
        
def C():
    if (((x==0 or j==0 or x==K-1)or((x==1 or x==K-2)and(j==K-1)))and(not((x==0 or x==K-1)and(j==0 or j==K-1)))):
        print('*',end='')
    else:
        print(' ',end='')
        
def D():
    if ((x==0 or j==0 or x==K-1 or j==K-1)and(not((x==0 or x==K-1)and(j==K-1)))):
        print('*',end='')
    else:
        print(' ',end='')

def E():
    if x==0 or x==K-1 or j==0 or x==K//2:
        print('*',end='')
    else:
        print(' ',end='')

def F():
    if x==0 or j==0 or x==K//2:
        print('*',end='')
    else:
        print(' ',end='')
        
def G():
    if (((x==0 or j==0 or x==K-1)or((x==1 or x==K-2)and(j==K-1))or((x>=K//(1.45))and(j==K-1 or j>=K//2)))and(not(((x>K//(1.45) and x<K-1)and(j>=K//2 and j<K-1))or((x==0 or x==K-1)and(j==0 or j==K-1))))):
        print('*',end='')
    else:
        print(' ',end='')
    
def H():
    if ((x==K//2 or j==0 or j==K-1)):
        print('*',end='')
    else:
        print(' ',end='')
    
def I():
    if x==0 or j==K//2 or x==K-1:
        print('*',end='')
    else:
        print(' ',end='')

def J():
    if (((x==K-1 and(j<=K//2 and j>=0))or(((x<=K-2 and x>(K//2)+1) and(j==0)))or x==0 or j==K//2))and(not(x==K-1 and(j==0 or j==K//2))):
        print('*',end='')
    else:
        print(' ',end='')
        
def Xo():
    global to,xo
    if x<K//2 and to>=1:
        ze=to-1
        le=xo
    if x>=K//2:
        ze=to+1
        le=xo+1
    if ((j==0) or(x<K//2 and j==to)):
        print('*',end='')
        to=ze
    elif (x==xo and j==to)or (x==K-1 and j==K-1):
        print('*',end='')
        to=ze
        xo=le
    else:
        print(' ',end='')
        
def L():
    if x==K-1 or j==0:
        print('*',end='')
    else:
        print(' ',end='')
        
def M():
    if (j==0 or j==K-1)or(x<=K//2 and(j==x or x+j==K-1)):
        print('*',end='')
    else:
        print(' ',end='')
        
def N():
    if j==0 or j==K-1 or j==x:
        print('*',end='')
    else:
        print(' ',end='')

def P():
    if j==0 or ((x==0 or x==K//2)and(j!=K-1))or(j==K-1 and(x>0 and x<K//2)):
        print('*',end='')
    else:
        print(' ',end='')
def Q():
    if ((j==0 or j==K-2)and(x<K-1 and x>0)) or ((x==0 or x==K-1)and(j>0 and j<K-2)) or (j==x and x>K//2):
        print('*',end='')
    else:
        print(' ',end='')
def R():
    if j==0 or (x==j and x>K//2) or ((x==0 or x==K//2)and(j!=K-1))or(j==K-1 and(x>0 and x<K//2)):
        print('*',end='')
    else:
        print(' ',end='') 
        
def S():
    if ((x==0 or x==K//2 or x==K-1)and(j>0 and j<K-1))or(j==0 and(x<K//2 and x>0))or(j==K-1 and(x>K//2 and x<K-1))or((x==1 and j==K-1)or(x==K-2 and(j==0))):
        print('*',end='')
    else:
        print(' ',end='')
def T():
    if x==0 or j==K//2:
        print('*',end='')
    else:
        print(' ',end='')
def x1():
    if x==j or j+x==K-1:
        print('*',end='')
    else:
        print(' ',end='')
def Y():
    if (j==K//2 and x>K//2)or(x==j or x+j==K-1)and(x<=K//2):
        print('*',end='')
    else:
        print(' ',end='')
def Z():
    if j+x==K-1 or x==0 or x==K-1:
        print('*',end='')
    else:
        print(' ',end='')
def W():
    if ((x==j or x+j==K-1)and(x>=K//2))or j==0 or j==K-1:
        print('*',end='')
    else:
        print(' ',end='')
def U():
    if (x==K-1 or j==0 or j==K-1)and not(x==K-1 and(j==0 or j==K-1)):
        print('*',end='')
    else:
        print(' ',end='')

def O():
    if((x==0 or x==K-1 or j==0 or j==K-1))and not((x==0 or x==K-1)and(j==0 or j==K-1)):
        print('*',end='')
    else:
        print(' ',end='')
        
def o():
    if((x==(K//2)-1 or x==K-1 or j==(K//2)-1 or j==K-1))and not(((x==(K//2)-1 or x==K-1)and(j==(K//2)-1 or j==K-1))or((j<(K//2)-1)or(x<(K//2)-1))):
        print('*',end='')
    else:
        print(' ',end='')
def u():
    if (x==K-1 or j==(K//2)-1 or j==K-1)and not((x==K-1 and(j==(K//2)-1 or j==K-1))or((x<(K//2)-1)or(j<(K//2)-1))):
        print('*',end='')
    else:
        print(' ',end='')
def X():
        if ((x==K-1)or(j==K//2)or(x==2 and (j<=(K//2)))) and not(x==1):
            print('*',end='')
        else:
            print(' ',end='')
def e():
        if (x==(K//2)-1 or x==K-1 or(j==K-1) or j==(K//2)-1 or x==((K//2)+(K//4)-1))and not((j<(K//2)-1)or ((x>(K//2)+(K//4)-1)and(j==K-1)) or(j==K-1 and(x==(K//2)-1))or(x<(K//2)-1)or((j==(K//2)-1)and(x==K-1 or x==(K//2)-1))):
            print('*',end='')
        else:
            print(' ',end='')
def a():
        if (x==(K//2)-1 or (j==(K//2)-1)or x==K-1 or x==((K//2)+(K//4))-1 or j==K-1)and not(((x<=((K//2)+(K//4))-1)and(j==(K//2)-1))or(x<(K//2)-1)or(j<(K//2)-1)or((x==K-1 or(x==(K//2)-1))and((j==(K//2)-1)or(j==K-1)))):
            print('*',end='')
        else:
            print(' ',end='')
n=input()
K=int(input())

d={'I':I,'U':U,'O':O,'A':A,'E':E,'o':o,'u':u,'i':X,'e':e,'a':a,'B':B,'C':C,'D':D,'F':F,'G':G,'H':H,'J':J,'K':Xo,'L':L,'M':M,'N':N,'P':P,'Q':Q,'R':R,'S':S,'T':T,'W':W,'X':x1,'Y':Y,'Z':Z}

if K>=7:
    if K%2==0:
        K+=1
        
    for i in n:
        if i in d:
            print()
            to=K-1
            xo=(K//2)
            for x in range(K):
                
                for j in range(K):
                    d[i]()
                print()
# Out:
# CHITKARA
# 9
#
#  *******
# *       *
# *
# *
# *
# *
# *
# *       *
#  *******
#
# *       *
# *       *
# *       *
# *       *
# *********
# *       *
# *       *
# *       *
# *       *
#
# *********
#     *
#     *
#     *
#     *
#     *
#     *
#     *
# *********
#
# *********
#     *
#     *
#     *
#     *
#     *
#     *
#     *
#     *
#
# *      *
# *    *
# *  *
# **
# **
# *  *
# *    *
# *      *
# *       *
#
#  *******
# *       *
# *       *
# *       *
# *********
# *       *
# *       *
# *       *
# *       *
#
# ********
# *       *
# *       *
# *       *
# ********
# *    *
# *     *
# *      *
# *       *
#
#  *******
# *       *
# *       *
# *       *
# *********
# *       *
# *       *
# *       *
# *       *
